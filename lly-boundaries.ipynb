# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import geopandas as gpd
import pandas as pd
import tiiradataframe as T

# %%
gdf = gpd.read_file('data/LLY-toimialue.gpkg', layer='LLY-toimialue')

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Maakunta  1 non-null      object
#  1   geometry  1 non-null      geometry
# dtypes: geometry(1), object(1)
# memory usage: 144.0+ bytes

# %%
gdf.bounds
# Out:
#           minx         miny         maxx          maxy
# 0  243238.7072  7286610.701  627859.7253  7.776493e+06

# %%
low_memory=False
df = T.read_csv('tiira.csv')

# %%
df.describe()
# Out:
#         Havainto id        X-koord       Y-koord  X-koord-linnun  \
# count  6.569000e+03    6569.000000  6.569000e+03     1761.000000
# mean   2.438512e+07  444642.310799  7.472729e+06   435197.396796
# std    4.888632e+04   63438.106906  1.176923e+05    71623.984462
# min    2.429903e+07  248301.458998  6.725462e+06   248266.093059
# 25%    2.434805e+07  382716.013821  7.376301e+06   355790.000000
# 50%    2.438468e+07  442565.000000  7.415461e+06   444951.000000
# 75%    2.442242e+07  490000.000000  7.571707e+06   485960.000000
# max    2.447810e+07  614731.000000  7.775678e+06   599639.000000
#
#        Y-koord-linnun  Atlaskoodi  Kuuluu havaintoon        Määrä  \
# count    1.761000e+03    8.000000                0.0  6569.000000
# mean     7.474874e+06   49.875000                NaN    10.977318
# std      1.174683e+05   37.631436                NaN    46.246124
# min      7.289315e+06    1.000000                NaN     0.000000
# ...

# %%
tgdf = T.addgeometries(df)
tgdf.set_crs(epsg=3067, inplace=True)
# Out:
#       Havainto id             Laji       Pvm1 Pvm2 Kello_hav_1 Kello_hav_2  \
# 0        24410732        sininärhi        NaT  NaT         NaN         NaN
# 1        24416164  punakylkirastas 2021-09-16  NaT         NaN         NaN
# 2        24364290     laulujoutsen 2021-09-06  NaT         NaN         NaN
# 3        24317712        pajulintu 2021-08-29  NaT    09:26:00         NaN
# 4        24321277      pikkusirkku 2021-08-29  NaT    05:00:00    12:35:00
# ...           ...              ...        ...  ...         ...         ...
# 6564     24370180    metsäkirvinen 2021-09-06  NaT         NaN         NaN
# 6565     24345064           peippo 2021-09-03  NaT    09:30:00         NaN
# 6566     24299972        urpiainen 2021-08-25  NaT    05:55:00    12:25:00
# 6567     24299972        urpiainen 2021-08-25  NaT    05:55:00    12:25:00
# 6568     24371231      pohjantikka 2021-09-07  NaT    05:30:00    14:00:00
#
# ...

# %%
pd.set_option("display.max_columns", None)
df.loc[df['Laji'] == 'sininärhi']
# Out:
#    Havainto id       Laji Pvm1 Pvm2 Kello_hav_1 Kello_hav_2      Kunta  \
# 0     24410732  sininärhi  NaT  NaT         NaN         NaN  Rovaniemi
#
#     Paikka   X-koord    Y-koord Tarkkuus  X-koord-linnun  Y-koord-linnun  \
# 0  Pekkala  494123.0  7358779.0    >5 km             NaN             NaN
#
#   Tarkkuus_linnun Paikannettu                       Lisätietoja  Atlaskoodi  \
# 0             NaN           X  Kirjattu ARK:n (LAHKO) listalta.         NaN
#
#     Tallentaja       Tallennusaika Havainnoijat Salattu Tallenteita  \
# 0  Esko Nevala 2021-09-15 18:19:05   Tuntematon     NaN         NaN
#
#   Koontihavainto  Kuuluu havaintoon  Määrä Kello_lintu_1 Kello_lintu_2  \
# 0            NaN                NaN    1.0           NaN           NaN
#
#   Sukupuoli Puku  Ikä Tila Lisätietoja_2  Parvi Bongattu Pesintä  \
# 0       NaN  NaN  NaN  NaN           NaN    NaN      NaN     NaN
#
#    Epäsuora havainto rivityyppi  rivejä                     Coordinates
# ...

# %%
tgdf = gpd.clip(tgdf, gdf)

# %%
sgdf = tgdf.loc[df['Laji'] == 'sininärhi']

# %%
ax = gdf.plot(color='lightblue', figsize=(16, 16))
tgdf.plot(marker='o', color='black', markersize=20, alpha=0.5, ax=ax);
sgdf.plot(marker='o', color='red', markersize=25, alpha=1, ax=ax);

# %%
tgdf.describe()
# Out:
#         Havainto id        X-koord       Y-koord  X-koord-linnun  \
# count  6.338000e+03    6338.000000  6.338000e+03     1999.000000
# mean   2.435295e+07  451652.607357  7.474069e+06   447823.059829
# std    4.484149e+04   63208.177282  1.178290e+05    73881.616533
# min    2.427259e+07  248301.458998  7.287887e+06   248266.093059
# 25%    2.431176e+07  418898.250000  7.376438e+06   367919.000000
# 50%    2.435720e+07  443312.141612  7.415824e+06   481623.000000
# 75%    2.438784e+07  502765.000000  7.579634e+06   502435.000000
# max    2.443582e+07  614731.000000  7.775678e+06   599639.000000
#
#        Y-koord-linnun  Atlaskoodi  Kuuluu havaintoon        Määrä  \
# count    1.999000e+03    6.000000                0.0  6338.000000
# mean     7.475493e+06   65.000000                NaN     8.945882
# std      1.146533e+05   29.658051                NaN    41.252821
# min      7.288022e+06    6.000000                NaN     0.000000
# ...
